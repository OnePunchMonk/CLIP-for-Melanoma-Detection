# %%
pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.44.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.16.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.24.7)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from sklearn.model_selection import train_test_split
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms

# Paths
DATASET_PATH = "/kaggle/input/isic-challenge-dataset-2020/ISIC_2020_Dataset"
TRAIN_IMAGES_PATH = os.path.join(DATASET_PATH, "train")
TEST_IMAGES_PATH = os.path.join(DATASET_PATH, "test")
TRAIN_METADATA_PATH = os.path.join(DATASET_PATH, "ISIC_2020_Train_Metadata.csv")
TEST_METADATA_PATH = os.path.join(DATASET_PATH, "ISIC_2020_Test_Metadata.csv")

# Load metadata
train_metadata = pd.read_csv(TRAIN_METADATA_PATH)
test_metadata = pd.read_csv(TEST_METADATA_PATH)

print("Train Metadata Loaded:", train_metadata.shape)
print("Test Metadata Loaded:", test_metadata.shape)

# Add file extension to image names in metadata
train_metadata['image_name_with_ext'] = train_metadata['image_name'] + '.jpg'

# List all image files in the train folder
train_image_files = set(os.listdir(TRAIN_IMAGES_PATH))

# Filter metadata for images that exist in the train folder
filtered_metadata = train_metadata[train_metadata['image_name_with_ext'].isin(train_image_files)]

print("\nFiltered Metadata Size After Validation:", len(filtered_metadata))

# Handle edge cases for labels with fewer than 2 samples
class_counts = filtered_metadata['diagnosis'].value_counts()
valid_classes = class_counts[class_counts > 1].index
filtered_metadata = filtered_metadata[filtered_metadata['diagnosis'].isin(valid_classes)]

print("\nFiltered Metadata Size After Removing Classes with Fewer Than 2 Samples:", len(filtered_metadata))

# Encode labels
label_mapping = {label: idx for idx, label in enumerate(filtered_metadata['diagnosis'].unique())}
filtered_metadata['label'] = filtered_metadata['diagnosis'].map(label_mapping)

print("\nUpdated Label Mapping:", label_mapping)

# Visualize sample images
def visualize_samples(image_dir, metadata, num_samples=6):
    if metadata.empty:
        print("\nNo valid samples to visualize. Metadata is empty.")
        return

    sample_images = metadata.sample(num_samples)
    plt.figure(figsize=(15, 10))
    for idx, (_, row) in enumerate(sample_images.iterrows()):
        img_path = os.path.join(image_dir, row['image_name_with_ext'])
        image = cv2.imread(img_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        plt.subplot(2, 3, idx + 1)
        plt.imshow(image)
        plt.title(f"Label: {row['diagnosis']}")
        plt.axis("off")
    plt.show()

print("\nVisualizing some training samples...")
visualize_samples(TRAIN_IMAGES_PATH, filtered_metadata)

# Split train and validation sets
if not filtered_metadata.empty:
    train_df, val_df = train_test_split(
        filtered_metadata, test_size=0.2, stratify=filtered_metadata['label'], random_state=42
    )

    print("\nTraining Set Size:", len(train_df))
    print("Validation Set Size:", len(val_df))
else:
    print("\nNo data to split for training and validation.")

# Define dataset class
class ISICDataset(Dataset):
    def __init__(self, metadata, image_dir, transform=None):
        self.metadata = metadata
        self.image_dir = image_dir
        self.transform = transform

    def __len__(self):
        return len(self.metadata)

    def __getitem__(self, idx):
        row = self.metadata.iloc[idx]
        img_path = os.path.join(self.image_dir, row['image_name_with_ext'])
        image = cv2.imread(img_path)
        if image is None:
            raise FileNotFoundError(f"Image not found at {img_path}")
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        label = row['label']
        if self.transform:
            image = self.transform(image)
        return image, label

# Data transformations
data_transforms = transforms.Compose([
    transforms.ToPILImage(),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# Create datasets and data loaders
if not filtered_metadata.empty:
    train_dataset = ISICDataset(train_df, TRAIN_IMAGES_PATH, transform=data_transforms)
    val_dataset = ISICDataset(val_df, TRAIN_IMAGES_PATH, transform=data_transforms)

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True, num_workers=4)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False, num_workers=4)

    print("\nData loaders created successfully.")

    # Test the data loader
    images, labels = next(iter(train_loader))
    print("\nSample Batch Shape (Images):", images.size())
    print("Sample Batch Shape (Labels):", labels.size())
else:
    print("\nNo valid data loaders created due to empty metadata.")
# Out:
# Train Metadata Loaded: (33126, 9)
# Test Metadata Loaded: (10982, 5)
#
# Filtered Metadata Size After Validation: 33126
#
# Filtered Metadata Size After Removing Classes with Fewer Than 2 Samples: 33124
#
# Updated Label Mapping: {'unknown': 0, 'nevus': 1, 'melanoma': 2, 'seborrheic keratosis': 3, 'lentigo NOS': 4, 'lichenoid keratosis': 5, 'solar lentigo': 6}
#
# Visualizing some training samples...
# Training Set Size: 26499
# Validation Set Size: 6625
#
# Data loaders created successfully.
#
# Sample Batch Shape (Images): torch.Size([32, 3, 224, 224])
# Sample Batch Shape (Labels): torch.Size([32])

# %%
import torch
import torch.nn as nn
from transformers import CLIPModel, CLIPProcessor

# Load the pre-trained CLIP model
clip_model = CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor = CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")

# Extract the vision encoder
vision_encoder = clip_model.vision_model

# Unfreeze the last 4-5 layers for fine-tuning
for name, param in vision_encoder.named_parameters():
    param.requires_grad = False  # Freeze all layers by default
    if "encoder.layers.10" in name or "encoder.layers.11" in name:
        param.requires_grad = True  # Unfreeze the last 2 layers
    if "final_layer_norm" in name:  # Also unfreeze the final normalization layer
        param.requires_grad = True

# Test the vision encoder output shape
dummy_input = torch.randn(1, 3, 224, 224)  # Batch size 1, RGB image of 224x224
vision_output = vision_encoder(dummy_input)

print("Vision Encoder Output Shape:", vision_output[0].shape)  # Shape: [batch_size, seq_length, hidden_dim]

# Add a custom feature extractor to adapt the vision encoder's output
class VisionFeatureExtractor(nn.Module):
    def __init__(self, vision_encoder, feature_dim=768):
        super(VisionFeatureExtractor, self).__init__()
        self.vision_encoder = vision_encoder
        self.avg_pool = nn.AdaptiveAvgPool1d(1)  # Pool across the sequence length
        self.feature_dim = feature_dim

    def forward(self, x):
        # Vision encoder output: [batch_size, seq_length, hidden_dim]
        vision_output = self.vision_encoder(x)[0]
        # Average pool across sequence dimension to reduce output: [batch_size, hidden_dim]
        pooled_output = self.avg_pool(vision_output.permute(0, 2, 1)).squeeze(-1)
        return pooled_output

# Instantiate the feature extractor
feature_extractor = VisionFeatureExtractor(vision_encoder)

# Test the feature extractor
extracted_features = feature_extractor(dummy_input)
print("Extracted Features Shape:", extracted_features.shape)  # Shape: [batch_size, hidden_dim]
# Out:
# config.json:   0%|          | 0.00/4.19k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/605M [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/316 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/592 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/862k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/525k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.22M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/389 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Vision Encoder Output Shape: torch.Size([1, 50, 768])
# Extracted Features Shape: torch.Size([1, 768])

# %%
import torch.nn as nn
import torch

# Define the CBAM Block
class CBAM(nn.Module):
    def __init__(self, channels, reduction_ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        # Channel Attention Module
        self.channel_attention = nn.Sequential(
            nn.AdaptiveAvgPool2d(1),
            nn.Conv2d(channels, channels // reduction_ratio, kernel_size=1, bias=False),
            nn.ReLU(),
            nn.Conv2d(channels // reduction_ratio, channels, kernel_size=1, bias=False),
            nn.Sigmoid(),
        )
        # Spatial Attention Module
        self.spatial_attention = nn.Sequential(
            nn.Conv2d(2, 1, kernel_size=kernel_size, padding=kernel_size // 2, bias=False),
            nn.Sigmoid(),
        )

    def forward(self, x):
        # Channel Attention
        channel_attention = self.channel_attention(x)
        x = x * channel_attention

        # Spatial Attention
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        spatial_attention_input = torch.cat([avg_out, max_out], dim=1)
        spatial_attention = self.spatial_attention(spatial_attention_input)
        x = x * spatial_attention

        return x


# Modify the VisionFeatureExtractor to include CBAM
class VisionFeatureExtractorWithCBAM(nn.Module):
    def __init__(self, vision_encoder, channels=768, reduction_ratio=16, kernel_size=7):
        super(VisionFeatureExtractorWithCBAM, self).__init__()
        self.vision_encoder = vision_encoder
        self.cbam = CBAM(channels, reduction_ratio, kernel_size)
        self.avg_pool = nn.AdaptiveAvgPool2d((1, 1))  # Pool across spatial dimensions

    def forward(self, x):
        # Pass through the vision encoder
        vision_output = self.vision_encoder(x)[0]  # Output: [batch_size, seq_length, hidden_dim]
        # Remove the [CLS] token (first token) from the sequence
        vision_output = vision_output[:, 1:, :]  # [batch_size, seq_length - 1, hidden_dim]

        # Reshape to 2D feature maps for CBAM (assuming seq_length is equivalent to spatial dimensions)
        b, seq_len, hidden_dim = vision_output.shape
        h = w = int(seq_len**0.5)  # Assuming the feature map is square
        if h * w != seq_len:
            raise ValueError(
                f"Sequence length ({seq_len}) does not form a square feature map (h={h}, w={w})."
            )
        vision_output_reshaped = vision_output.permute(0, 2, 1).reshape(b, hidden_dim, h, w)  # [batch_size, channels, height, width]

        # Pass through the CBAM block
        cbam_output = self.cbam(vision_output_reshaped)

        # Pool the CBAM output to a single feature vector per image
        pooled_output = self.avg_pool(cbam_output).squeeze(-1).squeeze(-1)  # [batch_size, channels]
        return pooled_output


# Instantiate the feature extractor with CBAM
feature_extractor_with_cbam = VisionFeatureExtractorWithCBAM(vision_encoder, channels=768)

# Test the feature extractor with CBAM
dummy_input = torch.randn(1, 3, 224, 224)  # Batch size 1, RGB image of 224x224
features_with_cbam = feature_extractor_with_cbam(dummy_input)
print("Features with CBAM Shape:", features_with_cbam.shape)  # Expected shape: [batch_size, channels]
# Out:
# Features with CBAM Shape: torch.Size([1, 768])

# %%
import torch.nn as nn

class SkinLesionClassifier(nn.Module):
    def __init__(self, vision_encoder, num_classes, channels=768, reduction_ratio=16, kernel_size=7):
        super(SkinLesionClassifier, self).__init__()
        # Feature extractor with CBAM
        self.feature_extractor = VisionFeatureExtractorWithCBAM(
            vision_encoder, channels=channels, reduction_ratio=reduction_ratio, kernel_size=kernel_size
        )
        # Classification head
        self.classifier = nn.Sequential(
            nn.Linear(channels, 256),  # Fully connected layer (reduce dimensionality to 256)
            nn.ReLU(),                # Activation
            nn.Dropout(0.5),          # Dropout for regularization
            nn.Linear(256, num_classes),  # Map to the number of classes
            nn.Softmax(dim=1)         # Softmax for classification probabilities
        )

    def forward(self, x):
        features = self.feature_extractor(x)  # Extract features using CBAM
        logits = self.classifier(features)    # Pass through the classification head
        return logits

# %%
import time

# Training configuration
num_epochs = 10  # Number of epochs to train
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Check GPU availability

# Training and Validation Loops
def train_and_evaluate(model, train_loader, val_loader, criterion, optimizer, num_epochs, device):
    print("\nStarting Training...")
    model = model.to(device)

    for epoch in range(num_epochs):
        # Training phase
        model.train()  # Set the model to training mode
        running_loss = 0.0
        train_correct = 0
        train_total = 0

        start_time = time.time()

        for batch_idx, (images, labels) in enumerate(train_loader):
            images, labels = images.to(device), labels.to(device)

            # Forward pass
            outputs = model(images)
            loss = criterion(outputs, labels)

            # Backward pass and optimization
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            # Track training loss and accuracy
            running_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            train_total += labels.size(0)
            train_correct += (predicted == labels).sum().item()

            # Print batch progress
            if (batch_idx + 1) % 10 == 0 or batch_idx == len(train_loader) - 1:  # Monitor every 10 batches
                print(
                    f"Epoch [{epoch + 1}/{num_epochs}], Batch [{batch_idx + 1}/{len(train_loader)}], "
                    f"Batch Loss: {loss.item():.4f}, "
                    f"Running Accuracy: {100 * train_correct / train_total:.2f}%"
                )

        epoch_loss = running_loss / len(train_loader)
        epoch_accuracy = 100 * train_correct / train_total
        end_time = time.time()

        print(
            f"\nEpoch [{epoch + 1}/{num_epochs}], "
            f"Training Loss: {epoch_loss:.4f}, "
            f"Training Accuracy: {epoch_accuracy:.2f}%, "
            f"Time: {end_time - start_time:.2f}s"
        )

        # Validation phase
        model.eval()  # Set the model to evaluation mode
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():  # Disable gradient calculation for validation
            for batch_idx, (images, labels) in enumerate(val_loader):
                images, labels = images.to(device), labels.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                _, predicted = torch.max(outputs, 1)
                val_total += labels.size(0)
                val_correct += (predicted == labels).sum().item()

                # Print batch progress
                if (batch_idx + 1) % 10 == 0 or batch_idx == len(val_loader) - 1:  # Monitor every 10 batches
                    print(
                        f"Validation Batch [{batch_idx + 1}/{len(val_loader)}], "
                        f"Running Validation Accuracy: {100 * val_correct / val_total:.2f}%"
                    )

        val_epoch_loss = val_loss / len(val_loader)
        val_epoch_accuracy = 100 * val_correct / val_total

        print(
            f"Validation Loss: {val_epoch_loss:.4f}, "
            f"Validation Accuracy: {val_epoch_accuracy:.2f}%\n"
        )

    print("Training Complete!")

# Assuming the VisionFeatureExtractorWithCBAM and all necessary imports are already defined above

# Define the number of classes (based on your dataset)
num_classes = len(label_mapping)  # Replace `label_mapping` with the actual mapping of classes in your dataset

# Instantiate the SkinLesionClassifier model
# vision_encoder = clip_model.visual  # Replace this with your actual vision encoder model (e.g., CLIP vision encoder)
skin_lesion_classifier = SkinLesionClassifier(
    vision_encoder=vision_encoder,
    num_classes=num_classes,
    channels=768,  # Adjust based on your vision encoder output dimension
    reduction_ratio=16,
    kernel_size=7
)

# Define the loss function and optimizer
criterion = nn.CrossEntropyLoss()  # Use CrossEntropyLoss for classification tasks
optimizer = torch.optim.Adam(skin_lesion_classifier.parameters(), lr=1e-4)

# Assuming `train_loader` and `val_loader` are already defined and contain the training and validation data loaders

# Training configuration
num_epochs = 10  # Number of epochs to train
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")  # Check GPU availability

# Call the function to train and evaluate
train_and_evaluate(
    model=skin_lesion_classifier,
    train_loader=train_loader,
    val_loader=val_loader,
    criterion=criterion,
    optimizer=optimizer,
    num_epochs=num_epochs,
    device=device
)


# # Call the function to train and evaluate
# train_and_evaluate(
#     model=skin_lesion_classifier,
#     train_loader=train_loader,
#     val_loader=val_loader,
#     criterion=criterion,
#     optimizer=optimizer,
#     num_epochs=num_epochs,
#     device=device
# )
# Out:
# Starting Training...
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Epoch [1/10], Batch [10/829], Batch Loss: 1.3478, Running Accuracy: 72.81%
# Epoch [1/10], Batch [20/829], Batch Loss: 1.3842, Running Accuracy: 75.31%
# Epoch [1/10], Batch [30/829], Batch Loss: 1.2904, Running Accuracy: 78.96%
# Epoch [1/10], Batch [40/829], Batch Loss: 1.4154, Running Accuracy: 80.16%
# Epoch [1/10], Batch [50/829], Batch Loss: 1.5092, Running Accuracy: 79.75%
# Epoch [1/10], Batch [60/829], Batch Loss: 1.3842, Running Accuracy: 79.95%
# Epoch [1/10], Batch [70/829], Batch Loss: 1.2279, Running Accuracy: 80.40%
# Epoch [1/10], Batch [80/829], Batch Loss: 1.3842, Running Accuracy: 80.43%
# Epoch [1/10], Batch [90/829], Batch Loss: 1.2592, Running Accuracy: 80.80%
# Epoch [1/10], Batch [100/829], Batch Loss: 1.3529, Running Accuracy: 80.91%
# Epoch [1/10], Batch [110/829], Batch Loss: 1.3529, Running Accuracy: 80.77%
# Epoch [1/10], Batch [120/829], Batch Loss: 1.2904, Running Accuracy: 80.89%
# Epoch [1/10], Batch [130/829], Batch Loss: 1.2904, Running Accuracy: 81.20%
# Epoch [1/10], Batch [140/829], Batch Loss: 1.3529, Running Accuracy: 81.56%
# Epoch [1/10], Batch [150/829], Batch Loss: 1.3217, Running Accuracy: 81.67%
# Epoch [1/10], Batch [160/829], Batch Loss: 1.4154, Running Accuracy: 81.46%
# Epoch [1/10], Batch [170/829], Batch Loss: 1.2904, Running Accuracy: 81.42%
# Epoch [1/10], Batch [180/829], Batch Loss: 1.4154, Running Accuracy: 81.46%
# Epoch [1/10], Batch [190/829], Batch Loss: 1.3529, Running Accuracy: 81.28%
# Epoch [1/10], Batch [200/829], Batch Loss: 1.2904, Running Accuracy: 81.48%
# Epoch [1/10], Batch [210/829], Batch Loss: 1.3529, Running Accuracy: 81.58%
# Epoch [1/10], Batch [220/829], Batch Loss: 1.4779, Running Accuracy: 81.46%
# Epoch [1/10], Batch [230/829], Batch Loss: 1.5717, Running Accuracy: 81.37%
# Epoch [1/10], Batch [240/829], Batch Loss: 1.3842, Running Accuracy: 81.33%
# Epoch [1/10], Batch [250/829], Batch Loss: 1.2904, Running Accuracy: 81.44%
# Epoch [1/10], Batch [260/829], Batch Loss: 1.3842, Running Accuracy: 81.38%
# Epoch [1/10], Batch [270/829], Batch Loss: 1.2592, Running Accuracy: 81.48%
# Epoch [1/10], Batch [280/829], Batch Loss: 1.3842, Running Accuracy: 81.45%
# Epoch [1/10], Batch [290/829], Batch Loss: 1.2904, Running Accuracy: 81.54%
# Epoch [1/10], Batch [300/829], Batch Loss: 1.3842, Running Accuracy: 81.55%
# Epoch [1/10], Batch [310/829], Batch Loss: 1.3842, Running Accuracy: 81.47%
# Epoch [1/10], Batch [320/829], Batch Loss: 1.2904, Running Accuracy: 81.46%
# Epoch [1/10], Batch [330/829], Batch Loss: 1.3842, Running Accuracy: 81.48%
# Epoch [1/10], Batch [340/829], Batch Loss: 1.3842, Running Accuracy: 81.48%
# Epoch [1/10], Batch [350/829], Batch Loss: 1.2904, Running Accuracy: 81.48%
# Epoch [1/10], Batch [360/829], Batch Loss: 1.3842, Running Accuracy: 81.57%
# Epoch [1/10], Batch [370/829], Batch Loss: 1.2904, Running Accuracy: 81.62%
# Epoch [1/10], Batch [380/829], Batch Loss: 1.3842, Running Accuracy: 81.64%
# Epoch [1/10], Batch [390/829], Batch Loss: 1.2279, Running Accuracy: 81.71%
# Epoch [1/10], Batch [400/829], Batch Loss: 1.4467, Running Accuracy: 81.70%
# Epoch [1/10], Batch [410/829], Batch Loss: 1.3217, Running Accuracy: 81.67%
# Epoch [1/10], Batch [420/829], Batch Loss: 1.4154, Running Accuracy: 81.70%
# Epoch [1/10], Batch [430/829], Batch Loss: 1.3217, Running Accuracy: 81.78%
# Epoch [1/10], Batch [440/829], Batch Loss: 1.5092, Running Accuracy: 81.74%
# Epoch [1/10], Batch [450/829], Batch Loss: 1.2592, Running Accuracy: 81.78%
# Epoch [1/10], Batch [460/829], Batch Loss: 1.2904, Running Accuracy: 81.77%
# Epoch [1/10], Batch [470/829], Batch Loss: 1.3217, Running Accuracy: 81.71%
# Epoch [1/10], Batch [480/829], Batch Loss: 1.3217, Running Accuracy: 81.66%
# Epoch [1/10], Batch [490/829], Batch Loss: 1.4779, Running Accuracy: 81.63%
# Epoch [1/10], Batch [500/829], Batch Loss: 1.2592, Running Accuracy: 81.67%
# Epoch [1/10], Batch [510/829], Batch Loss: 1.4467, Running Accuracy: 81.70%
# Epoch [1/10], Batch [520/829], Batch Loss: 1.3842, Running Accuracy: 81.70%
# Epoch [1/10], Batch [530/829], Batch Loss: 1.2592, Running Accuracy: 81.65%
# Epoch [1/10], Batch [540/829], Batch Loss: 1.3529, Running Accuracy: 81.67%
# Epoch [1/10], Batch [550/829], Batch Loss: 1.3217, Running Accuracy: 81.64%
# Epoch [1/10], Batch [560/829], Batch Loss: 1.3842, Running Accuracy: 81.69%
# Epoch [1/10], Batch [570/829], Batch Loss: 1.3842, Running Accuracy: 81.68%
# Epoch [1/10], Batch [580/829], Batch Loss: 1.4154, Running Accuracy: 81.71%
# Epoch [1/10], Batch [590/829], Batch Loss: 1.4154, Running Accuracy: 81.67%
# Epoch [1/10], Batch [600/829], Batch Loss: 1.4154, Running Accuracy: 81.70%
# Epoch [1/10], Batch [610/829], Batch Loss: 1.2279, Running Accuracy: 81.68%
# Epoch [1/10], Batch [620/829], Batch Loss: 1.3842, Running Accuracy: 81.68%
# Epoch [1/10], Batch [630/829], Batch Loss: 1.4779, Running Accuracy: 81.67%
# Epoch [1/10], Batch [640/829], Batch Loss: 1.2904, Running Accuracy: 81.69%
# Epoch [1/10], Batch [650/829], Batch Loss: 1.3217, Running Accuracy: 81.69%
# Epoch [1/10], Batch [660/829], Batch Loss: 1.3217, Running Accuracy: 81.72%
# Epoch [1/10], Batch [670/829], Batch Loss: 1.2592, Running Accuracy: 81.71%
# Epoch [1/10], Batch [680/829], Batch Loss: 1.3842, Running Accuracy: 81.72%
# Epoch [1/10], Batch [690/829], Batch Loss: 1.3217, Running Accuracy: 81.71%
# Epoch [1/10], Batch [700/829], Batch Loss: 1.3529, Running Accuracy: 81.75%
# Epoch [1/10], Batch [710/829], Batch Loss: 1.3842, Running Accuracy: 81.76%
# Epoch [1/10], Batch [720/829], Batch Loss: 1.3217, Running Accuracy: 81.77%
# Epoch [1/10], Batch [730/829], Batch Loss: 1.2592, Running Accuracy: 81.81%
# Epoch [1/10], Batch [740/829], Batch Loss: 1.5092, Running Accuracy: 81.83%
# Epoch [1/10], Batch [750/829], Batch Loss: 1.3842, Running Accuracy: 81.82%

# Validation Batch [10/208], Running Validation Accuracy: 80.00%
# Validation Batch [20/208], Running Validation Accuracy: 80.94%
# Validation Batch [30/208], Running Validation Accuracy: 81.25%
# Validation Batch [40/208], Running Validation Accuracy: 80.62%
# Validation Batch [50/208], Running Validation Accuracy: 80.75%
# Validation Batch [60/208], Running Validation Accuracy: 81.25%
# Validation Batch [70/208], Running Validation Accuracy: 81.47%
# Validation Batch [80/208], Running Validation Accuracy: 81.60%
# Validation Batch [90/208], Running Validation Accuracy: 81.63%
# Validation Batch [100/208], Running Validation Accuracy: 81.81%
# Validation Batch [110/208], Running Validation Accuracy: 81.70%
# Validation Batch [120/208], Running Validation Accuracy: 82.03%
# Validation Batch [130/208], Running Validation Accuracy: 82.14%
# Validation Batch [140/208], Running Validation Accuracy: 82.19%
# Validation Batch [150/208], Running Validation Accuracy: 82.08%
# Validation Batch [160/208], Running Validation Accuracy: 81.78%
# Validation Batch [170/208], Running Validation Accuracy: 81.91%
# Validation Batch [180/208], Running Validation Accuracy: 81.89%
# Validation Batch [190/208], Running Validation Accuracy: 81.84%
# Validation Batch [200/208], Running Validation Accuracy: 81.78%
# Validation Batch [208/208], Running Validation Accuracy: 81.89%
# Validation Loss: 1.3457, Validation Accuracy: 81.89%
#
# Epoch [4/10], Batch [10/829], Batch Loss: 1.2279, Running Accuracy: 84.38%
# Epoch [4/10], Batch [20/829], Batch Loss: 1.3529, Running Accuracy: 80.62%
# Epoch [4/10], Batch [30/829], Batch Loss: 1.3217, Running Accuracy: 80.10%
# Epoch [4/10], Batch [40/829], Batch Loss: 1.2904, Running Accuracy: 81.33%
# Epoch [4/10], Batch [50/829], Batch Loss: 1.3842, Running Accuracy: 81.19%
# Epoch [4/10], Batch [60/829], Batch Loss: 1.2592, Running Accuracy: 81.35%
# Epoch [4/10], Batch [70/829], Batch Loss: 1.3217, Running Accuracy: 81.74%
# Epoch [4/10], Batch [80/829], Batch Loss: 1.3217, Running Accuracy: 81.84%
# Epoch [4/10], Batch [90/829], Batch Loss: 1.2592, Running Accuracy: 81.49%
# Epoch [4/10], Batch [100/829], Batch Loss: 1.3842, Running Accuracy: 81.69%
# Epoch [4/10], Batch [110/829], Batch Loss: 1.3529, Running Accuracy: 81.70%
# Epoch [4/10], Batch [120/829], Batch Loss: 1.2592, Running Accuracy: 81.85%
# Epoch [4/10], Batch [130/829], Batch Loss: 1.3842, Running Accuracy: 81.61%
# Epoch [4/10], Batch [140/829], Batch Loss: 1.2904, Running Accuracy: 81.54%
# Epoch [4/10], Batch [150/829], Batch Loss: 1.4154, Running Accuracy: 81.71%
# Epoch [4/10], Batch [160/829], Batch Loss: 1.2904, Running Accuracy: 81.74%
# Epoch [4/10], Batch [170/829], Batch Loss: 1.4154, Running Accuracy: 81.45%
# Epoch [4/10], Batch [180/829], Batch Loss: 1.3217, Running Accuracy: 81.53%
# Epoch [4/10], Batch [190/829], Batch Loss: 1.3529, Running Accuracy: 81.41%
# Epoch [4/10], Batch [200/829], Batch Loss: 1.3529, Running Accuracy: 81.39%
# Epoch [4/10], Batch [210/829], Batch Loss: 1.3529, Running Accuracy: 81.38%
# Epoch [4/10], Batch [220/829], Batch Loss: 1.3529, Running Accuracy: 81.41%
# Epoch [4/10], Batch [230/829], Batch Loss: 1.2904, Running Accuracy: 81.49%
# Epoch [4/10], Batch [240/829], Batch Loss: 1.3842, Running Accuracy: 81.46%
# Epoch [4/10], Batch [250/829], Batch Loss: 1.2904, Running Accuracy: 81.30%
# Epoch [4/10], Batch [260/829], Batch Loss: 1.3217, Running Accuracy: 81.47%
# Epoch [4/10], Batch [270/829], Batch Loss: 1.2904, Running Accuracy: 81.38%
# Epoch [4/10], Batch [280/829], Batch Loss: 1.3529, Running Accuracy: 81.19%
# Epoch [4/10], Batch [290/829], Batch Loss: 1.5404, Running Accuracy: 81.31%
# Epoch [4/10], Batch [300/829], Batch Loss: 1.2904, Running Accuracy: 81.32%
# Epoch [4/10], Batch [310/829], Batch Loss: 1.3529, Running Accuracy: 81.32%
# Epoch [4/10], Batch [320/829], Batch Loss: 1.4779, Running Accuracy: 81.36%
# Epoch [4/10], Batch [330/829], Batch Loss: 1.3842, Running Accuracy: 81.33%
# Epoch [4/10], Batch [340/829], Batch Loss: 1.3529, Running Accuracy: 81.23%
# Epoch [4/10], Batch [350/829], Batch Loss: 1.4154, Running Accuracy: 81.18%
# Epoch [4/10], Batch [360/829], Batch Loss: 1.4154, Running Accuracy: 81.12%
# Epoch [4/10], Batch [370/829], Batch Loss: 1.3529, Running Accuracy: 81.26%
# Epoch [4/10], Batch [380/829], Batch Loss: 1.2904, Running Accuracy: 81.38%
# Epoch [4/10], Batch [390/829], Batch Loss: 1.3217, Running Accuracy: 81.31%
# Epoch [4/10], Batch [400/829], Batch Loss: 1.3529, Running Accuracy: 81.38%
# Epoch [4/10], Batch [410/829], Batch Loss: 1.2279, Running Accuracy: 81.42%
# Epoch [4/10], Batch [420/829], Batch Loss: 1.3842, Running Accuracy: 81.48%
# Epoch [4/10], Batch [430/829], Batch Loss: 1.3217, Running Accuracy: 81.53%
# Epoch [4/10], Batch [440/829], Batch Loss: 1.2904, Running Accuracy: 81.56%
# Epoch [4/10], Batch [450/829], Batch Loss: 1.4154, Running Accuracy: 81.49%
# Epoch [4/10], Batch [460/829], Batch Loss: 1.3529, Running Accuracy: 81.49%
# Epoch [4/10], Batch [470/829], Batch Loss: 1.2279, Running Accuracy: 81.60%
# Epoch [4/10], Batch [480/829], Batch Loss: 1.2279, Running Accuracy: 81.61%
# Epoch [4/10], Batch [490/829], Batch Loss: 1.4154, Running Accuracy: 81.64%
# Epoch [4/10], Batch [500/829], Batch Loss: 1.3842, Running Accuracy: 81.66%
# Epoch [4/10], Batch [510/829], Batch Loss: 1.3217, Running Accuracy: 81.70%
# Epoch [4/10], Batch [520/829], Batch Loss: 1.3842, Running Accuracy: 81.70%
# Epoch [4/10], Batch [530/829], Batch Loss: 1.3529, Running Accuracy: 81.69%
# Epoch [4/10], Batch [540/829], Batch Loss: 1.3217, Running Accuracy: 81.69%
# Epoch [4/10], Batch [550/829], Batch Loss: 1.2904, Running Accuracy: 81.73%
# Epoch [4/10], Batch [560/829], Batch Loss: 1.2904, Running Accuracy: 81.77%
# Epoch [4/10], Batch [570/829], Batch Loss: 1.2904, Running Accuracy: 81.82%
# Epoch [4/10], Batch [580/829], Batch Loss: 1.2904, Running Accuracy: 81.78%
# Epoch [4/10], Batch [590/829], Batch Loss: 1.4154, Running Accuracy: 81.78%
# Epoch [4/10], Batch [600/829], Batch Loss: 1.3529, Running Accuracy: 81.79%
# Epoch [4/10], Batch [610/829], Batch Loss: 1.3529, Running Accuracy: 81.77%
# Epoch [4/10], Batch [620/829], Batch Loss: 1.2592, Running Accuracy: 81.81%
# Epoch [4/10], Batch [630/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [4/10], Batch [640/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [4/10], Batch [650/829], Batch Loss: 1.2904, Running Accuracy: 81.87%
# Epoch [4/10], Batch [660/829], Batch Loss: 1.3217, Running Accuracy: 81.87%
# Epoch [4/10], Batch [670/829], Batch Loss: 1.2904, Running Accuracy: 81.84%
# Epoch [4/10], Batch [680/829], Batch Loss: 1.3529, Running Accuracy: 81.81%
# Epoch [4/10], Batch [690/829], Batch Loss: 1.3529, Running Accuracy: 81.81%
# Epoch [4/10], Batch [700/829], Batch Loss: 1.3529, Running Accuracy: 81.79%
# Epoch [4/10], Batch [710/829], Batch Loss: 1.3217, Running Accuracy: 81.80%
# Epoch [4/10], Batch [720/829], Batch Loss: 1.4779, Running Accuracy: 81.80%
# Epoch [4/10], Batch [730/829], Batch Loss: 1.4154, Running Accuracy: 81.79%
# Epoch [4/10], Batch [740/829], Batch Loss: 1.2592, Running Accuracy: 81.83%
# Epoch [4/10], Batch [750/829], Batch Loss: 1.4154, Running Accuracy: 81.88%
# Epoch [4/10], Batch [760/829], Batch Loss: 1.3217, Running Accuracy: 81.93%
# Epoch [4/10], Batch [770/829], Batch Loss: 1.2904, Running Accuracy: 81.94%
# Epoch [4/10], Batch [780/829], Batch Loss: 1.4779, Running Accuracy: 81.93%
# Epoch [4/10], Batch [790/829], Batch Loss: 1.3842, Running Accuracy: 81.92%
# Epoch [4/10], Batch [800/829], Batch Loss: 1.3842, Running Accuracy: 81.89%
# Epoch [4/10], Batch [810/829], Batch Loss: 1.4779, Running Accuracy: 81.88%
# Epoch [4/10], Batch [820/829], Batch Loss: 1.3842, Running Accuracy: 81.87%
# Epoch [4/10], Batch [829/829], Batch Loss: 1.4988, Running Accuracy: 81.89%
#
# Epoch [4/10], Training Loss: 1.3467, Training Accuracy: 81.89%, Time: 2291.66s
# Validation Batch [10/208], Running Validation Accuracy: 80.00%
# Validation Batch [20/208], Running Validation Accuracy: 80.94%
# Validation Batch [30/208], Running Validation Accuracy: 81.25%
# Validation Batch [40/208], Running Validation Accuracy: 80.62%
# Validation Batch [50/208], Running Validation Accuracy: 80.75%
# Validation Batch [60/208], Running Validation Accuracy: 81.25%
# Validation Batch [70/208], Running Validation Accuracy: 81.47%
# Validation Batch [80/208], Running Validation Accuracy: 81.60%
# Validation Batch [90/208], Running Validation Accuracy: 81.63%
# Validation Batch [100/208], Running Validation Accuracy: 81.81%
# Validation Batch [110/208], Running Validation Accuracy: 81.70%
# Validation Batch [120/208], Running Validation Accuracy: 82.03%
# Validation Batch [130/208], Running Validation Accuracy: 82.14%
# Validation Batch [140/208], Running Validation Accuracy: 82.19%
# Validation Batch [150/208], Running Validation Accuracy: 82.08%
# Validation Batch [160/208], Running Validation Accuracy: 81.78%
# Validation Batch [170/208], Running Validation Accuracy: 81.91%
# Validation Batch [180/208], Running Validation Accuracy: 81.89%
# Validation Batch [190/208], Running Validation Accuracy: 81.84%
# Validation Batch [200/208], Running Validation Accuracy: 81.78%
# Validation Batch [208/208], Running Validation Accuracy: 81.89%
# Validation Loss: 1.3457, Validation Accuracy: 81.89%
#
# Epoch [5/10], Batch [10/829], Batch Loss: 1.3217, Running Accuracy: 82.19%
# Epoch [5/10], Batch [20/829], Batch Loss: 1.3529, Running Accuracy: 83.28%
# Epoch [5/10], Batch [30/829], Batch Loss: 1.2592, Running Accuracy: 83.23%
# Epoch [5/10], Batch [40/829], Batch Loss: 1.3842, Running Accuracy: 83.05%
# Epoch [5/10], Batch [50/829], Batch Loss: 1.3529, Running Accuracy: 82.75%
# Epoch [5/10], Batch [60/829], Batch Loss: 1.3217, Running Accuracy: 82.81%
# Epoch [5/10], Batch [70/829], Batch Loss: 1.3842, Running Accuracy: 82.63%
# Epoch [5/10], Batch [80/829], Batch Loss: 1.2592, Running Accuracy: 82.73%
# Epoch [5/10], Batch [90/829], Batch Loss: 1.4467, Running Accuracy: 82.78%
# Epoch [5/10], Batch [100/829], Batch Loss: 1.2592, Running Accuracy: 82.97%
# Epoch [5/10], Batch [110/829], Batch Loss: 1.2279, Running Accuracy: 82.73%
# Epoch [5/10], Batch [120/829], Batch Loss: 1.3217, Running Accuracy: 82.55%
# Epoch [5/10], Batch [130/829], Batch Loss: 1.3217, Running Accuracy: 82.50%
# Epoch [5/10], Batch [140/829], Batch Loss: 1.2592, Running Accuracy: 82.59%
# Epoch [5/10], Batch [150/829], Batch Loss: 1.3529, Running Accuracy: 82.31%
# Epoch [5/10], Batch [160/829], Batch Loss: 1.3529, Running Accuracy: 82.36%
# Epoch [5/10], Batch [170/829], Batch Loss: 1.3842, Running Accuracy: 82.35%
# Epoch [5/10], Batch [180/829], Batch Loss: 1.2279, Running Accuracy: 82.17%
# Epoch [5/10], Batch [190/829], Batch Loss: 1.2904, Running Accuracy: 82.20%
# Epoch [5/10], Batch [200/829], Batch Loss: 1.3217, Running Accuracy: 82.12%
# Epoch [5/10], Batch [210/829], Batch Loss: 1.3529, Running Accuracy: 82.14%
# Epoch [5/10], Batch [220/829], Batch Loss: 1.4779, Running Accuracy: 82.13%
# Epoch [5/10], Batch [230/829], Batch Loss: 1.3529, Running Accuracy: 82.13%
# Epoch [5/10], Batch [240/829], Batch Loss: 1.2279, Running Accuracy: 81.95%
# Epoch [5/10], Batch [250/829], Batch Loss: 1.3217, Running Accuracy: 81.95%
# Epoch [5/10], Batch [260/829], Batch Loss: 1.3217, Running Accuracy: 81.95%
# Epoch [5/10], Batch [270/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [5/10], Batch [280/829], Batch Loss: 1.2279, Running Accuracy: 81.95%
# Epoch [5/10], Batch [290/829], Batch Loss: 1.2592, Running Accuracy: 81.90%
# Epoch [5/10], Batch [300/829], Batch Loss: 1.3217, Running Accuracy: 81.96%
# Epoch [5/10], Batch [310/829], Batch Loss: 1.3529, Running Accuracy: 82.02%
# Epoch [5/10], Batch [320/829], Batch Loss: 1.3842, Running Accuracy: 81.91%
# Epoch [5/10], Batch [330/829], Batch Loss: 1.4467, Running Accuracy: 81.88%
# Epoch [5/10], Batch [340/829], Batch Loss: 1.3842, Running Accuracy: 81.90%
# Epoch [5/10], Batch [350/829], Batch Loss: 1.3217, Running Accuracy: 81.83%
# Epoch [5/10], Batch [360/829], Batch Loss: 1.3529, Running Accuracy: 81.89%
# Epoch [5/10], Batch [370/829], Batch Loss: 1.4154, Running Accuracy: 81.85%
# Epoch [5/10], Batch [380/829], Batch Loss: 1.2904, Running Accuracy: 81.84%
# Epoch [5/10], Batch [390/829], Batch Loss: 1.2904, Running Accuracy: 81.83%
# Epoch [5/10], Batch [400/829], Batch Loss: 1.3217, Running Accuracy: 81.97%
# Epoch [5/10], Batch [410/829], Batch Loss: 1.3217, Running Accuracy: 82.00%
# Epoch [5/10], Batch [420/829], Batch Loss: 1.3529, Running Accuracy: 81.94%
# Epoch [5/10], Batch [430/829], Batch Loss: 1.2592, Running Accuracy: 82.01%
# Epoch [5/10], Batch [440/829], Batch Loss: 1.4154, Running Accuracy: 81.88%
# Epoch [5/10], Batch [450/829], Batch Loss: 1.3529, Running Accuracy: 81.87%
# Epoch [5/10], Batch [460/829], Batch Loss: 1.4779, Running Accuracy: 81.81%
# Epoch [5/10], Batch [470/829], Batch Loss: 1.4467, Running Accuracy: 81.78%
# Epoch [5/10], Batch [480/829], Batch Loss: 1.3217, Running Accuracy: 81.90%
# Epoch [5/10], Batch [490/829], Batch Loss: 1.3529, Running Accuracy: 81.97%
# Epoch [5/10], Batch [500/829], Batch Loss: 1.2904, Running Accuracy: 81.92%
# Epoch [5/10], Batch [510/829], Batch Loss: 1.2904, Running Accuracy: 81.97%
# Epoch [5/10], Batch [520/829], Batch Loss: 1.3529, Running Accuracy: 82.02%
# Epoch [5/10], Batch [530/829], Batch Loss: 1.2904, Running Accuracy: 82.02%
# Epoch [5/10], Batch [540/829], Batch Loss: 1.2904, Running Accuracy: 82.08%
# Epoch [5/10], Batch [550/829], Batch Loss: 1.3842, Running Accuracy: 82.03%
# Epoch [5/10], Batch [560/829], Batch Loss: 1.3529, Running Accuracy: 82.00%
# Epoch [5/10], Batch [570/829], Batch Loss: 1.3529, Running Accuracy: 82.02%
# Epoch [5/10], Batch [580/829], Batch Loss: 1.3529, Running Accuracy: 82.02%
# Epoch [5/10], Batch [590/829], Batch Loss: 1.4779, Running Accuracy: 81.98%
# Epoch [5/10], Batch [600/829], Batch Loss: 1.3529, Running Accuracy: 81.94%
# Epoch [5/10], Batch [610/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [5/10], Batch [620/829], Batch Loss: 1.3842, Running Accuracy: 81.86%
# Epoch [5/10], Batch [630/829], Batch Loss: 1.4154, Running Accuracy: 81.86%
# Epoch [5/10], Batch [640/829], Batch Loss: 1.2904, Running Accuracy: 81.84%
# Epoch [5/10], Batch [650/829], Batch Loss: 1.4779, Running Accuracy: 81.80%
# Epoch [5/10], Batch [660/829], Batch Loss: 1.3529, Running Accuracy: 81.79%
# Epoch [5/10], Batch [670/829], Batch Loss: 1.3217, Running Accuracy: 81.76%
# Epoch [5/10], Batch [680/829], Batch Loss: 1.4154, Running Accuracy: 81.74%
# Epoch [5/10], Batch [690/829], Batch Loss: 1.3529, Running Accuracy: 81.70%
# Epoch [5/10], Batch [700/829], Batch Loss: 1.2904, Running Accuracy: 81.76%
# Epoch [5/10], Batch [710/829], Batch Loss: 1.3529, Running Accuracy: 81.86%
# Epoch [5/10], Batch [720/829], Batch Loss: 1.2904, Running Accuracy: 81.86%
# Epoch [5/10], Batch [730/829], Batch Loss: 1.2592, Running Accuracy: 81.93%
# Epoch [5/10], Batch [740/829], Batch Loss: 1.4154, Running Accuracy: 81.94%
# Epoch [5/10], Batch [750/829], Batch Loss: 1.2904, Running Accuracy: 81.90%
# Epoch [5/10], Batch [760/829], Batch Loss: 1.3529, Running Accuracy: 81.94%
# Epoch [5/10], Batch [770/829], Batch Loss: 1.4154, Running Accuracy: 81.90%
# Epoch [5/10], Batch [780/829], Batch Loss: 1.5092, Running Accuracy: 81.90%
# Epoch [5/10], Batch [790/829], Batch Loss: 1.2904, Running Accuracy: 81.91%
# Epoch [5/10], Batch [800/829], Batch Loss: 1.3217, Running Accuracy: 81.88%
# Epoch [5/10], Batch [810/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [5/10], Batch [820/829], Batch Loss: 1.5092, Running Accuracy: 81.86%
# Epoch [5/10], Batch [829/829], Batch Loss: 1.1654, Running Accuracy: 81.89%
#
# Epoch [5/10], Training Loss: 1.3464, Training Accuracy: 81.89%, Time: 2294.32s
# Validation Batch [10/208], Running Validation Accuracy: 80.00%
# Validation Batch [20/208], Running Validation Accuracy: 80.94%
# Validation Batch [30/208], Running Validation Accuracy: 81.25%
# Validation Batch [40/208], Running Validation Accuracy: 80.62%
# Validation Batch [50/208], Running Validation Accuracy: 80.75%
# Validation Batch [60/208], Running Validation Accuracy: 81.25%
# Validation Batch [70/208], Running Validation Accuracy: 81.47%
# Validation Batch [80/208], Running Validation Accuracy: 81.60%
# Validation Batch [90/208], Running Validation Accuracy: 81.63%
# Validation Batch [100/208], Running Validation Accuracy: 81.81%
# Validation Batch [110/208], Running Validation Accuracy: 81.70%
# Validation Batch [120/208], Running Validation Accuracy: 82.03%
# Validation Batch [130/208], Running Validation Accuracy: 82.14%
# Validation Batch [140/208], Running Validation Accuracy: 82.19%
# Validation Batch [150/208], Running Validation Accuracy: 82.08%
# Validation Batch [160/208], Running Validation Accuracy: 81.78%
# Validation Batch [170/208], Running Validation Accuracy: 81.91%
# Validation Batch [180/208], Running Validation Accuracy: 81.89%
# Validation Batch [190/208], Running Validation Accuracy: 81.84%
# Validation Batch [200/208], Running Validation Accuracy: 81.78%
# Validation Batch [208/208], Running Validation Accuracy: 81.89%
# Validation Loss: 1.3457, Validation Accuracy: 81.89%
#
# Epoch [6/10], Batch [10/829], Batch Loss: 1.4154, Running Accuracy: 83.12%
# Epoch [6/10], Batch [20/829], Batch Loss: 1.4154, Running Accuracy: 80.62%
# Epoch [6/10], Batch [30/829], Batch Loss: 1.3529, Running Accuracy: 81.35%
# Epoch [6/10], Batch [40/829], Batch Loss: 1.2904, Running Accuracy: 81.17%
# Epoch [6/10], Batch [50/829], Batch Loss: 1.4154, Running Accuracy: 81.31%
# Epoch [6/10], Batch [410/829], Batch Loss: 1.2592, Running Accuracy: 82.00%
# Epoch [6/10], Batch [420/829], Batch Loss: 1.2904, Running Accuracy: 81.95%
# Epoch [6/10], Batch [430/829], Batch Loss: 1.3842, Running Accuracy: 81.95%
# Epoch [6/10], Batch [440/829], Batch Loss: 1.3217, Running Accuracy: 81.89%
# Epoch [6/10], Batch [450/829], Batch Loss: 1.2904, Running Accuracy: 81.92%
# Epoch [6/10], Batch [460/829], Batch Loss: 1.4779, Running Accuracy: 81.82%
# Epoch [6/10], Batch [470/829], Batch Loss: 1.3217, Running Accuracy: 81.79%
# Epoch [6/10], Batch [480/829], Batch Loss: 1.3217, Running Accuracy: 81.81%
# Epoch [6/10], Batch [490/829], Batch Loss: 1.3217, Running Accuracy: 81.83%
# Epoch [6/10], Batch [500/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [6/10], Batch [510/829], Batch Loss: 1.2279, Running Accuracy: 81.82%
# Epoch [6/10], Batch [520/829], Batch Loss: 1.4467, Running Accuracy: 81.79%
# Epoch [6/10], Batch [530/829], Batch Loss: 1.3217, Running Accuracy: 81.84%
# Epoch [6/10], Batch [540/829], Batch Loss: 1.3529, Running Accuracy: 81.81%
# Epoch [6/10], Batch [550/829], Batch Loss: 1.3217, Running Accuracy: 81.81%
# Epoch [6/10], Batch [560/829], Batch Loss: 1.2904, Running Accuracy: 81.81%
# Epoch [6/10], Batch [570/829], Batch Loss: 1.3842, Running Accuracy: 81.79%
# Epoch [6/10], Batch [580/829], Batch Loss: 1.3842, Running Accuracy: 81.74%
# Epoch [6/10], Batch [590/829], Batch Loss: 1.3842, Running Accuracy: 81.74%
# Epoch [6/10], Batch [600/829], Batch Loss: 1.2592, Running Accuracy: 81.79%
# Epoch [6/10], Batch [610/829], Batch Loss: 1.3217, Running Accuracy: 81.81%
# Epoch [6/10], Batch [620/829], Batch Loss: 1.2279, Running Accuracy: 81.83%
# Epoch [6/10], Batch [630/829], Batch Loss: 1.2904, Running Accuracy: 81.86%
# Epoch [6/10], Batch [640/829], Batch Loss: 1.4154, Running Accuracy: 81.85%
# Epoch [6/10], Batch [650/829], Batch Loss: 1.4154, Running Accuracy: 81.82%
# Epoch [6/10], Batch [660/829], Batch Loss: 1.3529, Running Accuracy: 81.78%
# Epoch [6/10], Batch [670/829], Batch Loss: 1.2592, Running Accuracy: 81.82%
# Epoch [6/10], Batch [680/829], Batch Loss: 1.3217, Running Accuracy: 81.82%
# Epoch [6/10], Batch [690/829], Batch Loss: 1.3842, Running Accuracy: 81.80%
# Epoch [6/10], Batch [700/829], Batch Loss: 1.4779, Running Accuracy: 81.79%
# Epoch [6/10], Batch [710/829], Batch Loss: 1.4779, Running Accuracy: 81.74%
# Epoch [6/10], Batch [720/829], Batch Loss: 1.4779, Running Accuracy: 81.70%
# Epoch [6/10], Batch [730/829], Batch Loss: 1.4154, Running Accuracy: 81.70%
# Epoch [6/10], Batch [740/829], Batch Loss: 1.4154, Running Accuracy: 81.74%
# Epoch [6/10], Batch [750/829], Batch Loss: 1.4467, Running Accuracy: 81.79%
# Epoch [9/10], Batch [120/829], Batch Loss: 1.3842, Running Accuracy: 82.76%
# Epoch [9/10], Batch [130/829], Batch Loss: 1.4467, Running Accuracy: 82.67%
# Epoch [9/10], Batch [140/829], Batch Loss: 1.2904, Running Accuracy: 82.77%
# Epoch [9/10], Batch [150/829], Batch Loss: 1.2592, Running Accuracy: 82.73%
# Epoch [9/10], Batch [160/829], Batch Loss: 1.3217, Running Accuracy: 82.52%
# Epoch [9/10], Batch [170/829], Batch Loss: 1.4467, Running Accuracy: 82.57%
# Epoch [9/10], Batch [180/829], Batch Loss: 1.4467, Running Accuracy: 82.22%
# Epoch [9/10], Batch [190/829], Batch Loss: 1.2592, Running Accuracy: 82.29%
# Epoch [9/10], Batch [200/829], Batch Loss: 1.3842, Running Accuracy: 82.45%
# Epoch [9/10], Batch [210/829], Batch Loss: 1.3217, Running Accuracy: 82.50%
# Epoch [9/10], Batch [220/829], Batch Loss: 1.3529, Running Accuracy: 82.50%
# Epoch [9/10], Batch [230/829], Batch Loss: 1.3217, Running Accuracy: 82.46%
# Epoch [9/10], Batch [240/829], Batch Loss: 1.4467, Running Accuracy: 82.54%
# Epoch [9/10], Batch [250/829], Batch Loss: 1.2592, Running Accuracy: 82.58%
# Epoch [9/10], Batch [260/829], Batch Loss: 1.3217, Running Accuracy: 82.46%
# Epoch [9/10], Batch [270/829], Batch Loss: 1.3217, Running Accuracy: 82.36%
# Epoch [9/10], Batch [280/829], Batch Loss: 1.2904, Running Accuracy: 82.27%
# Epoch [9/10], Batch [290/829], Batch Loss: 1.5092, Running Accuracy: 82.16%
# Epoch [9/10], Batch [300/829], Batch Loss: 1.2904, Running Accuracy: 82.10%
# Epoch [9/10], Batch [310/829], Batch Loss: 1.3529, Running Accuracy: 82.10%
# Epoch [9/10], Batch [320/829], Batch Loss: 1.2592, Running Accuracy: 82.13%
# Epoch [9/10], Batch [330/829], Batch Loss: 1.2904, Running Accuracy: 82.07%
# Epoch [9/10], Batch [340/829], Batch Loss: 1.4154, Running Accuracy: 82.07%
# Epoch [9/10], Batch [350/829], Batch Loss: 1.2279, Running Accuracy: 82.12%
# Epoch [9/10], Batch [360/829], Batch Loss: 1.4154, Running Accuracy: 82.15%
# Epoch [9/10], Batch [370/829], Batch Loss: 1.3217, Running Accuracy: 82.20%
# Epoch [9/10], Batch [380/829], Batch Loss: 1.3217, Running Accuracy: 82.27%
# Epoch [9/10], Batch [390/829], Batch Loss: 1.3842, Running Accuracy: 82.19%
# Epoch [9/10], Batch [400/829], Batch Loss: 1.3529, Running Accuracy: 82.13%
# Epoch [9/10], Batch [410/829], Batch Loss: 1.3529, Running Accuracy: 82.21%
# Epoch [9/10], Batch [420/829], Batch Loss: 1.2904, Running Accuracy: 82.25%
# Epoch [9/10], Batch [430/829], Batch Loss: 1.3529, Running Accuracy: 82.34%
# Epoch [9/10], Batch [440/829], Batch Loss: 1.2279, Running Accuracy: 82.30%
# Epoch [9/10], Batch [450/829], Batch Loss: 1.3529, Running Accuracy: 82.24%
# Epoch [9/10], Batch [460/829], Batch Loss: 1.2279, Running Accuracy: 82.24%
# Epoch [9/10], Batch [470/829], Batch Loss: 1.3217, Running Accuracy: 82.15%
# Epoch [9/10], Batch [480/829], Batch Loss: 1.3842, Running Accuracy: 82.09%
# Epoch [9/10], Batch [490/829], Batch Loss: 1.3529, Running Accuracy: 82.06%
# Epoch [9/10], Batch [500/829], Batch Loss: 1.2904, Running Accuracy: 82.06%
# Epoch [9/10], Batch [510/829], Batch Loss: 1.4467, Running Accuracy: 82.02%
# Epoch [9/10], Batch [520/829], Batch Loss: 1.2592, Running Accuracy: 82.08%
# Epoch [9/10], Batch [530/829], Batch Loss: 1.3529, Running Accuracy: 82.10%
# Epoch [9/10], Batch [540/829], Batch Loss: 1.2904, Running Accuracy: 82.14%
# Epoch [9/10], Batch [550/829], Batch Loss: 1.3842, Running Accuracy: 82.14%
# Epoch [9/10], Batch [560/829], Batch Loss: 1.3529, Running Accuracy: 82.11%
# Epoch [9/10], Batch [570/829], Batch Loss: 1.2904, Running Accuracy: 82.13%
# Epoch [9/10], Batch [580/829], Batch Loss: 1.3842, Running Accuracy: 82.14%
# Epoch [9/10], Batch [590/829], Batch Loss: 1.3842, Running Accuracy: 82.11%
# Epoch [9/10], Batch [600/829], Batch Loss: 1.2904, Running Accuracy: 82.14%
# Epoch [9/10], Batch [610/829], Batch Loss: 1.4154, Running Accuracy: 82.16%
# Epoch [9/10], Batch [620/829], Batch Loss: 1.3529, Running Accuracy: 82.13%
# Epoch [9/10], Batch [630/829], Batch Loss: 1.4154, Running Accuracy: 82.13%
# Epoch [9/10], Batch [640/829], Batch Loss: 1.2592, Running Accuracy: 82.12%
# Epoch [9/10], Batch [650/829], Batch Loss: 1.2904, Running Accuracy: 82.17%
# Epoch [9/10], Batch [660/829], Batch Loss: 1.4154, Running Accuracy: 82.16%
# Epoch [9/10], Batch [670/829], Batch Loss: 1.2904, Running Accuracy: 82.14%
# Epoch [9/10], Batch [680/829], Batch Loss: 1.3842, Running Accuracy: 82.09%
# Epoch [9/10], Batch [690/829], Batch Loss: 1.5404, Running Accuracy: 82.08%
# Epoch [9/10], Batch [700/829], Batch Loss: 1.4154, Running Accuracy: 82.04%
# Epoch [9/10], Batch [710/829], Batch Loss: 1.3217, Running Accuracy: 81.99%
# Epoch [9/10], Batch [720/829], Batch Loss: 1.2904, Running Accuracy: 81.98%
# Epoch [9/10], Batch [730/829], Batch Loss: 1.4467, Running Accuracy: 81.99%
# Epoch [9/10], Batch [740/829], Batch Loss: 1.3529, Running Accuracy: 82.00%
# Epoch [9/10], Batch [750/829], Batch Loss: 1.3217, Running Accuracy: 81.98%
# Epoch [9/10], Batch [760/829], Batch Loss: 1.4467, Running Accuracy: 81.90%
# Epoch [9/10], Batch [770/829], Batch Loss: 1.2904, Running Accuracy: 81.92%
# Epoch [9/10], Batch [780/829], Batch Loss: 1.3217, Running Accuracy: 81.90%
# Epoch [9/10], Batch [790/829], Batch Loss: 1.2904, Running Accuracy: 81.89%
# Epoch [9/10], Batch [800/829], Batch Loss: 1.3529, Running Accuracy: 81.89%
# Epoch [9/10], Batch [810/829], Batch Loss: 1.2904, Running Accuracy: 81.88%
# Epoch [9/10], Batch [820/829], Batch Loss: 1.4467, Running Accuracy: 81.88%
# Epoch [9/10], Batch [829/829], Batch Loss: 1.4988, Running Accuracy: 81.89%
#
# Epoch [9/10], Training Loss: 1.3467, Training Accuracy: 81.89%, Time: 2140.24s
# Validation Batch [10/208], Running Validation Accuracy: 80.00%
# Validation Batch [20/208], Running Validation Accuracy: 80.94%
# Validation Batch [30/208], Running Validation Accuracy: 81.25%
# Validation Batch [40/208], Running Validation Accuracy: 80.62%
# Validation Batch [50/208], Running Validation Accuracy: 80.75%
# Validation Batch [60/208], Running Validation Accuracy: 81.25%
# Validation Batch [70/208], Running Validation Accuracy: 81.47%
# Validation Batch [80/208], Running Validation Accuracy: 81.60%
# Validation Batch [90/208], Running Validation Accuracy: 81.63%
# Validation Batch [100/208], Running Validation Accuracy: 81.81%
# Validation Batch [110/208], Running Validation Accuracy: 81.70%
# Validation Batch [120/208], Running Validation Accuracy: 82.03%
# Validation Batch [130/208], Running Validation Accuracy: 82.14%
# Validation Batch [140/208], Running Validation Accuracy: 82.19%
# Validation Batch [150/208], Running Validation Accuracy: 82.08%
# Validation Batch [160/208], Running Validation Accuracy: 81.78%
# Validation Batch [170/208], Running Validation Accuracy: 81.91%
# Validation Batch [180/208], Running Validation Accuracy: 81.89%
# Validation Batch [190/208], Running Validation Accuracy: 81.84%
# Validation Batch [200/208], Running Validation Accuracy: 81.78%
# Validation Batch [208/208], Running Validation Accuracy: 81.89%
# Validation Loss: 1.3457, Validation Accuracy: 81.89%
#
#
# Epoch [10/10], Batch [310/829], Batch Loss: 1.4779, Running Accuracy: 81.36%
# Epoch [10/10], Batch [320/829], Batch Loss: 1.3529, Running Accuracy: 81.39%
# Epoch [10/10], Batch [330/829], Batch Loss: 1.5092, Running Accuracy: 81.22%
# Epoch [10/10], Batch [340/829], Batch Loss: 1.4467, Running Accuracy: 81.32%
# Epoch [10/10], Batch [350/829], Batch Loss: 1.3842, Running Accuracy: 81.29%
# Epoch [10/10], Batch [360/829], Batch Loss: 1.2592, Running Accuracy: 81.32%
# Epoch [10/10], Batch [370/829], Batch Loss: 1.3842, Running Accuracy: 81.39%
# Epoch [10/10], Batch [380/829], Batch Loss: 1.2279, Running Accuracy: 81.50%
# Epoch [10/10], Batch [390/829], Batch Loss: 1.2904, Running Accuracy: 81.53%
# Epoch [10/10], Batch [400/829], Batch Loss: 1.4467, Running Accuracy: 81.62%
# Epoch [10/10], Batch [410/829], Batch Loss: 1.3217, Running Accuracy: 81.62%
# Epoch [10/10], Batch [420/829], Batch Loss: 1.4467, Running Accuracy: 81.65%
# Epoch [10/10], Batch [430/829], Batch Loss: 1.3529, Running Accuracy: 81.70%
# Epoch [10/10], Batch [440/829], Batch Loss: 1.3529, Running Accuracy: 81.68%
# Epoch [10/10], Batch [450/829], Batch Loss: 1.3217, Running Accuracy: 81.67%
# Epoch [10/10], Batch [460/829], Batch Loss: 1.3217, Running Accuracy: 81.75%
# Epoch [10/10], Batch [470/829], Batch Loss: 1.4154, Running Accuracy: 81.73%
# Epoch [10/10], Batch [480/829], Batch Loss: 1.2279, Running Accuracy: 81.78%
# Epoch [10/10], Batch [490/829], Batch Loss: 1.4779, Running Accuracy: 81.80%
# Epoch [10/10], Batch [500/829], Batch Loss: 1.2904, Running Accuracy: 81.79%
# Epoch [10/10], Batch [510/829], Batch Loss: 1.3842, Running Accuracy: 81.81%
# Epoch [10/10], Batch [520/829], Batch Loss: 1.2904, Running Accuracy: 81.80%
# Epoch [10/10], Batch [530/829], Batch Loss: 1.3529, Running Accuracy: 81.84%
# Epoch [10/10], Batch [540/829], Batch Loss: 1.3217, Running Accuracy: 81.79%
# Epoch [10/10], Batch [550/829], Batch Loss: 1.2279, Running Accuracy: 81.81%
# Epoch [10/10], Batch [560/829], Batch Loss: 1.2904, Running Accuracy: 81.77%
# Epoch [10/10], Batch [570/829], Batch Loss: 1.4154, Running Accuracy: 81.78%
# Epoch [10/10], Batch [580/829], Batch Loss: 1.4779, Running Accuracy: 81.76%
# Epoch [10/10], Batch [590/829], Batch Loss: 1.3529, Running Accuracy: 81.76%
# Epoch [10/10], Batch [600/829], Batch Loss: 1.3842, Running Accuracy: 81.78%
# Epoch [10/10], Batch [610/829], Batch Loss: 1.3529, Running Accuracy: 81.81%
# Epoch [10/10], Batch [620/829], Batch Loss: 1.4154, Running Accuracy: 81.77%
# Epoch [10/10], Batch [630/829], Batch Loss: 1.3529, Running Accuracy: 81.80%
# Epoch [10/10], Batch [640/829], Batch Loss: 1.4154, Running Accuracy: 81.81%
# Epoch [10/10], Batch [650/829], Batch Loss: 1.3842, Running Accuracy: 81.82%
# Epoch [10/10], Batch [660/829], Batch Loss: 1.3529, Running Accuracy: 81.82%
# Epoch [10/10], Batch [670/829], Batch Loss: 1.2592, Running Accuracy: 81.90%
# Epoch [10/10], Batch [680/829], Batch Loss: 1.2904, Running Accuracy: 81.93%
# Epoch [10/10], Batch [690/829], Batch Loss: 1.3217, Running Accuracy: 81.88%
# Epoch [10/10], Batch [700/829], Batch Loss: 1.3217, Running Accuracy: 81.85%
# Epoch [10/10], Batch [710/829], Batch Loss: 1.3217, Running Accuracy: 81.87%
# Epoch [10/10], Batch [720/829], Batch Loss: 1.3529, Running Accuracy: 81.93%
# Epoch [10/10], Batch [730/829], Batch Loss: 1.4467, Running Accuracy: 81.89%
# Epoch [10/10], Batch [740/829], Batch Loss: 1.3842, Running Accuracy: 81.90%
# Epoch [10/10], Batch [750/829], Batch Loss: 1.3529, Running Accuracy: 81.91%
# Epoch [10/10], Batch [760/829], Batch Loss: 1.3529, Running Accuracy: 81.88%
# Epoch [10/10], Batch [770/829], Batch Loss: 1.2592, Running Accuracy: 81.86%
# Epoch [10/10], Batch [780/829], Batch Loss: 1.3217, Running Accuracy: 81.87%
# Epoch [10/10], Batch [790/829], Batch Loss: 1.3529, Running Accuracy: 81.85%
# Epoch [10/10], Batch [800/829], Batch Loss: 1.2592, Running Accuracy: 81.88%
# Epoch [10/10], Batch [810/829], Batch Loss: 1.4467, Running Accuracy: 81.87%
# Epoch [10/10], Batch [820/829], Batch Loss: 1.4154, Running Accuracy: 81.87%
# Epoch [10/10], Batch [829/829], Batch Loss: 1.8321, Running Accuracy: 81.89%
#
# Epoch [10/10], Training Loss: 1.3471, Training Accuracy: 81.89%, Time: 2298.67s
# Validation Batch [10/208], Running Validation Accuracy: 80.00%
# Validation Batch [20/208], Running Validation Accuracy: 80.94%
# Validation Batch [30/208], Running Validation Accuracy: 81.25%
# Validation Batch [40/208], Running Validation Accuracy: 80.62%
# Validation Batch [50/208], Running Validation Accuracy: 80.75%
# Validation Batch [60/208], Running Validation Accuracy: 81.25%
# Validation Batch [70/208], Running Validation Accuracy: 81.47%
# Validation Batch [80/208], Running Validation Accuracy: 81.60%
# Validation Batch [90/208], Running Validation Accuracy: 81.63%
# Validation Batch [100/208], Running Validation Accuracy: 81.81%
# Validation Batch [110/208], Running Validation Accuracy: 81.70%
# Validation Batch [120/208], Running Validation Accuracy: 82.03%
# Validation Batch [130/208], Running Validation Accuracy: 82.14%
# Validation Batch [140/208], Running Validation Accuracy: 82.19%
# Validation Batch [150/208], Running Validation Accuracy: 82.08%
# Validation Batch [160/208], Running Validation Accuracy: 81.78%
# Validation Batch [170/208], Running Validation Accuracy: 81.91%
# Validation Batch [180/208], Running Validation Accuracy: 81.89%
# Validation Batch [190/208], Running Validation Accuracy: 81.84%
# Validation Batch [200/208], Running Validation Accuracy: 81.78%
# Validation Batch [208/208], Running Validation Accuracy: 81.89%
# Validation Loss: 1.3457, Validation Accuracy: 81.89%
#
# Training Complete!
